# %%
#Verifico la capacidad de GPU
# !nvidia-smi
# Out:
# Sun Nov 24 12:18:15 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.01             Driver Version: 537.70       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4050 ...    On  | 00000000:01:00.0 Off |                  N/A |
# | N/A   36C    P8               1W /  85W |   3481MiB /  6141MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A    317209      C   /python3.12                               N/A      |
# |    0   N/A  N/A    317211      C   /python3.12                               N/A      |
# |    0   N/A  N/A    366948      C   /python3.12                               N/A      |
# +---------------------------------------------------------------------------------------+

# %%
#Librerias a importar
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets, models, transforms

# %%
# Transformación para entrenamiento
train_transform = transforms.Compose([
    transforms.Resize(256),  # Cambia el tamaño para hacer el recorte centrado
    transforms.CenterCrop(224),  # Asegura el recorte centrado
    transforms.RandomHorizontalFlip(),  # Flip horizontal para aumentar los datos
    transforms.RandomVerticalFlip(),  # Flip vertical para aumentar los datos
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Transformaciones para validación
val_transform = transforms.Compose([
    transforms.Resize(256),  # Asegura el redimensionado
    transforms.CenterCrop(224),  # Recorta centrado
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Transformaciones para prueba
test_transform = transforms.Compose([
    transforms.Resize(256),  # Asegura el redimensionado
    transforms.CenterCrop(224),  # Recorta centrado
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])


# Cargar los datos con las nuevas transformaciones
train_dataset = torchvision.datasets.ImageFolder(root='/home/aloha/Lun9ntbk/imagenes_vehiculos/train', transform=train_transform)
val_dataset = torchvision.datasets.ImageFolder(root='/home/aloha/Lun9ntbk/imagenes_vehiculos/val', transform=val_transform)
test_dataset = torchvision.datasets.ImageFolder(root='/home/aloha/Lun9ntbk/imagenes_vehiculos/test', transform=test_transform)

print(train_dataset)
print(val_dataset)
print(test_dataset)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 1800
#     Root location: /home/aloha/Lun9ntbk/imagenes_vehiculos/train
#     StandardTransform
# Transform: Compose(
#                Resize(size=256, interpolation=bilinear, max_size=None, antialias=True)
#                CenterCrop(size=(224, 224))
#                RandomHorizontalFlip(p=0.5)
#                RandomVerticalFlip(p=0.5)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )
# Dataset ImageFolder
#     Number of datapoints: 300
#     Root location: /home/aloha/Lun9ntbk/imagenes_vehiculos/val
#     StandardTransform
# Transform: Compose(
#                Resize(size=256, interpolation=bilinear, max_size=None, antialias=True)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )
# Dataset ImageFolder
#     Number of datapoints: 300
#     Root location: /home/aloha/Lun9ntbk/imagenes_vehiculos/test
#     StandardTransform
# Transform: Compose(
#                Resize(size=256, interpolation=bilinear, max_size=None, antialias=True)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
# Imprimo un resumen de los datos
print('Train:', len(train_dataset))
# Out:
# Train: 1800

# %%
import os
from torch.utils.data.sampler import SubsetRandomSampler # type: ignore

batch_size = 4
learning_rate = 0.001
num_epocas = 50
step_log = 100
num_workers = os.cpu_count()

# Porcentaje de datos de validación
valid_size = 0.20  # 20% para validación

# Obtener los índices para el dataset de entrenamiento y dividir para validación
num_train = len(train_dataset)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# Definir los samplers para entrenamiento y validación
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# Definir DataLoaders para entrenamiento, validación y test
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,
                                           sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,
                                           sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,
                                          shuffle=True, num_workers=num_workers)

class_names = train_dataset.classes

print(f"Usando {num_workers} workers para cargar datos.")
# Out:
# Usando 16 workers para cargar datos.

# %%
# Imprimo el nombre de las clases
class_names = train_dataset.classes
print(train_dataset.classes)
# Out:
# ['Autos', 'Microbuses', 'Motos']

# %%
# Cargo un batch de imagenes
def imshow(inp, title = None):
  inp = inp.numpy().transpose((1, 2, 0))
  mean = np.array([0.485, 0.456, 0.406])
  std = np.array([0.229, 0.224, 0.225])
  inp = std * inp + mean
  inp = np.clip(inp, 0, 1)
  plt.imshow(inp)
  
  if title is not None:
    plt.title(title)
  plt.pause(0.001)
  
dataiter = iter(train_loader)
inputs, classes = next(dataiter)

out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
# Se grafican nuevamente, pero con los nombres de las clases truncados
def imshow_with_class_name(inp, class_name, ax=None):   
    
    if ax is None:
        ax = plt.gca()

    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    ax.imshow(inp)

      # Limit class name to 15 characters using slicing
    max_length = 15
    title = class_name[:max_length]  # Truncate at the specified index
    if len(class_name) > max_length:
        title += "..."  # Add ellipsis to indicate truncation

    ax.set_title(title, fontsize=8, ha='center', va='top')

dataiter = iter(train_loader)
inputs, classes = next(dataiter)

# Crear una cuadrícula de 2 filas y 2 columnas
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

# Mostrar las imágenes y los nombres de las clases en cada subplot
for i, (inp, class_name) in enumerate(zip(inputs, classes)):
    row = i // 2
    col = i % 2
    imshow_with_class_name(inp, class_names[class_name], axes[row, col])

# Eliminar bordes y espacios entre subplots
plt.tight_layout()
plt.show()

# %%
torch.cuda.set_device(0) 
device = ('cuda' if torch.cuda.is_available() else 'cpu')

print("Se entrenara con:", device)
# Out:
# Se entrenara con: cuda

# %%
# Imprimo el numero de clases
num_classes = len(class_names)
print(num_classes)
# Out:
# 3

# %%
class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()
        self.conv1 = nn.Conv2d(3, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 256, kernel_size=3)
        self.bn1 = nn.BatchNorm2d(256)
        self.conv3 = nn.Conv2d(256, 512, kernel_size=3)
        
        self.fc1 = nn.Linear(512*26*26, 50)  # 50 neuronas en la capa densa
        self.fc2 = nn.Linear(50, 3)  # 2 salidas: una para la media y otra para la log-varianza

    def forward(self, x):
        # Aplicación de convoluciones + ReLU + Pooling
        x = F.max_pool2d(F.relu(self.conv1(x)), 2)
        x = F.max_pool2d(F.relu(self.bn1(self.conv2(x))), 2)
        x = F.max_pool2d(F.relu(self.conv3(x)), 2)
        x = x.view(-1, self.num_flat_features(x))
        x = F.relu(self.fc1(x))
        x = self.fc2(x)

        return F.softmax(x, dim=-1)
    
    def num_flat_features(self, x):
        size = x.size()[1:]  # todas las dimensiones excepto la del batch
        num_features = 1
        for s in size:
            num_features *= s
        return num_features

# Instanciar el modelo
network = Network()

# %%
model = network.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)

# %%
import os
import json

# Definir funciones para cargar y guardar métricas
def load_metrics(file_path):
    if os.path.exists(file_path):
        with open(file_path, 'r') as f:
            return json.load(f)
    return {"train_losses": [], "valid_losses": [], "accuracy_train_list": [], "accuracy_valid_list": []}

def save_metrics(file_path, metrics):
    with open(file_path, 'w') as f:
        json.dump(metrics, f)

# Ruta del archivo donde se guardarán las métricas
metrics_file = 'metrics_01.json'
metrics = load_metrics(metrics_file)

# Cargar las métricas anteriores
train_losses = metrics["train_losses"]
valid_losses = metrics["valid_losses"]
accuracy_train_list = metrics["accuracy_train_list"]
accuracy_valid_list = metrics["accuracy_valid_list"]

# Definir parámetros
valid_loss_min = min(valid_losses) if valid_losses else float('inf')  # Valor mínimo de valid_loss si existe

# Bucle de entrenamiento por épocas
for epoch in range(1, num_epocas + 1):
    # Inicializar las pérdidas de entrenamiento y validación
    train_loss = 0.0
    valid_loss = 0.0
    correct_train = 0  # Para contar las predicciones correctas en el entrenamiento
    total_train = 0  # Para contar el total de muestras de entrenamiento
    correct_valid = 0  # Para contar las predicciones correctas en la validación
    total_valid = 0  # Para contar el total de muestras de validación

    # ---- Entrenamiento ----
    model.train()  # Poner el modelo en modo de entrenamiento
    for data, target in train_loader:
        data, target = data.to(device), target.to(device)

        optimizer.zero_grad()  # Limpiar los gradientes
        output = model(data)  # Forward pass
        loss = criterion(output, target)  # Calcular la pérdida de entrenamiento
        loss.backward()  # Backward pass
        optimizer.step()  # Optimización

        train_loss += loss.item() * data.size(0)  # Actualizar pérdida
        _, pred = torch.max(output, dim=1)  # Predicciones
        correct_train += (pred == target).sum().item()  # Sumar correctas
        total_train += target.size(0)  # Total muestras

    # ---- Validación ----
    model.eval()  # Modo evaluación
    with torch.no_grad():
        for data, target in valid_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            loss = criterion(output, target)  # Calcular la pérdida de validación
            valid_loss += loss.item() * data.size(0)
            _, pred = torch.max(output, dim=1)
            correct_valid += (pred == target).sum().item()
            total_valid += target.size(0)

    # Calcular las pérdidas promediadas
    train_loss = train_loss / len(train_loader.sampler)
    valid_loss = valid_loss / len(valid_loader.sampler)

    # Calcular la precisión promedio en entrenamiento y validación
    train_accuracy = 100 * correct_train / total_train
    valid_accuracy = 100 * correct_valid / total_valid

    # Guardar las pérdidas y las precisiones
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)
    accuracy_train_list.append(train_accuracy)
    accuracy_valid_list.append(valid_accuracy)

    # Imprimir resultados por época
    print(f'Epoch: {epoch}/{num_epocas}')
    print(f'Training Loss: {train_loss:.6f} \tValidation Loss: {valid_loss:.6f}')
    print(f'Training Accuracy: {train_accuracy:.2f}% \tValidation Accuracy: {valid_accuracy:.2f}%')

    # Guardar el modelo si la pérdida de validación ha disminuido
    if valid_loss <= valid_loss_min:
        print(f'Validation loss decreased ({valid_loss_min:.6f} --> {valid_loss:.6f}). Saving model ...')
        torch.save(model.state_dict(), 'vehicle_propio_cross.pt')  # Guardar modelo
        valid_loss_min = valid_loss  # Actualizar mejor pérdida

    # Guardar métricas actualizadas
    save_metrics(metrics_file, {
        "train_losses": train_losses,
        "valid_losses": valid_losses,
        "accuracy_train_list": accuracy_train_list,
        "accuracy_valid_list": accuracy_valid_list
    })

# Finalización del entrenamiento
print("Entrenamiento completo")
# Out:
# Epoch: 1/50
# Training Loss: 1.082662 	Validation Loss: 1.055184
# Training Accuracy: 39.86% 	Validation Accuracy: 43.06%
# Validation loss decreased (inf --> 1.055184). Saving model ...
# Epoch: 2/50
# Training Loss: 1.012048 	Validation Loss: 0.979758
# Training Accuracy: 53.40% 	Validation Accuracy: 56.94%
# Validation loss decreased (1.055184 --> 0.979758). Saving model ...
# Epoch: 3/50
# Training Loss: 0.961333 	Validation Loss: 0.941447
# Training Accuracy: 58.33% 	Validation Accuracy: 61.11%
# Validation loss decreased (0.979758 --> 0.941447). Saving model ...
# Epoch: 4/50
# Training Loss: 0.928705 	Validation Loss: 0.910448
# Training Accuracy: 63.75% 	Validation Accuracy: 64.72%
# Validation loss decreased (0.941447 --> 0.910448). Saving model ...
# Epoch: 5/50
# Training Loss: 0.892353 	Validation Loss: 0.921218
# Training Accuracy: 66.67% 	Validation Accuracy: 59.44%
# Epoch: 6/50
# Training Loss: 0.865806 	Validation Loss: 0.899626
# Training Accuracy: 69.51% 	Validation Accuracy: 65.28%
# Validation loss decreased (0.910448 --> 0.899626). Saving model ...
# Epoch: 7/50
# Training Loss: 0.838858 	Validation Loss: 0.856378
# Training Accuracy: 72.08% 	Validation Accuracy: 68.33%
# Validation loss decreased (0.899626 --> 0.856378). Saving model ...
# Epoch: 8/50
# Training Loss: 0.817993 	Validation Loss: 0.837420
# Training Accuracy: 73.82% 	Validation Accuracy: 70.28%
# Validation loss decreased (0.856378 --> 0.837420). Saving model ...
# Epoch: 9/50
# Training Loss: 0.797117 	Validation Loss: 0.837216
# Training Accuracy: 76.94% 	Validation Accuracy: 72.50%
# Validation loss decreased (0.837420 --> 0.837216). Saving model ...
# Epoch: 10/50
# Training Loss: 0.776142 	Validation Loss: 0.823666
# Training Accuracy: 78.54% 	Validation Accuracy: 72.78%
# Validation loss decreased (0.837216 --> 0.823666). Saving model ...
# Epoch: 11/50
# Training Loss: 0.761083 	Validation Loss: 0.808193
# Training Accuracy: 79.79% 	Validation Accuracy: 74.17%
# Validation loss decreased (0.823666 --> 0.808193). Saving model ...
# Epoch: 12/50
# Training Loss: 0.743310 	Validation Loss: 0.817496
# Training Accuracy: 81.25% 	Validation Accuracy: 73.06%
# Epoch: 13/50
# Training Loss: 0.735070 	Validation Loss: 0.798285
# Training Accuracy: 83.06% 	Validation Accuracy: 74.72%
# Validation loss decreased (0.808193 --> 0.798285). Saving model ...
# Epoch: 14/50
# Training Loss: 0.723138 	Validation Loss: 0.787198
# Training Accuracy: 83.47% 	Validation Accuracy: 76.67%
# Validation loss decreased (0.798285 --> 0.787198). Saving model ...
# Epoch: 15/50
# Training Loss: 0.716697 	Validation Loss: 0.798619
# Training Accuracy: 84.31% 	Validation Accuracy: 74.44%
# Epoch: 16/50
# Training Loss: 0.713196 	Validation Loss: 0.774719
# Training Accuracy: 84.38% 	Validation Accuracy: 77.22%
# Validation loss decreased (0.787198 --> 0.774719). Saving model ...
# Epoch: 17/50
# Training Loss: 0.701948 	Validation Loss: 0.777510
# Training Accuracy: 85.83% 	Validation Accuracy: 77.50%
# Epoch: 18/50
# Training Loss: 0.691203 	Validation Loss: 0.757340
# Training Accuracy: 87.36% 	Validation Accuracy: 80.00%
# Validation loss decreased (0.774719 --> 0.757340). Saving model ...
# Epoch: 19/50
# Training Loss: 0.681569 	Validation Loss: 0.766725
# Training Accuracy: 87.85% 	Validation Accuracy: 78.61%
# Epoch: 20/50
# Training Loss: 0.675285 	Validation Loss: 0.756748
# Training Accuracy: 88.96% 	Validation Accuracy: 79.17%
# Validation loss decreased (0.757340 --> 0.756748). Saving model ...
# Epoch: 21/50
# Training Loss: 0.670748 	Validation Loss: 0.784785
# Training Accuracy: 88.89% 	Validation Accuracy: 77.50%
# Epoch: 22/50
# Training Loss: 0.663297 	Validation Loss: 0.760871
# Training Accuracy: 89.93% 	Validation Accuracy: 80.00%
# Epoch: 23/50
# Training Loss: 0.662382 	Validation Loss: 0.748073
# Training Accuracy: 89.58% 	Validation Accuracy: 79.72%
# Validation loss decreased (0.756748 --> 0.748073). Saving model ...
# Epoch: 24/50
# Training Loss: 0.652274 	Validation Loss: 0.758448
# Training Accuracy: 91.39% 	Validation Accuracy: 79.17%
# Epoch: 25/50
# Training Loss: 0.646623 	Validation Loss: 0.745822
# Training Accuracy: 91.04% 	Validation Accuracy: 79.72%
# Validation loss decreased (0.748073 --> 0.745822). Saving model ...
# Epoch: 26/50
# Training Loss: 0.647277 	Validation Loss: 0.727347
# Training Accuracy: 91.32% 	Validation Accuracy: 82.78%
# Validation loss decreased (0.745822 --> 0.727347). Saving model ...
# Epoch: 27/50
# Training Loss: 0.638634 	Validation Loss: 0.742143
# Training Accuracy: 92.15% 	Validation Accuracy: 80.28%
# Epoch: 28/50
# Training Loss: 0.633477 	Validation Loss: 0.740241
# Training Accuracy: 92.99% 	Validation Accuracy: 80.28%
# Epoch: 29/50
# Training Loss: 0.635354 	Validation Loss: 0.754826
# Training Accuracy: 92.15% 	Validation Accuracy: 78.61%
# Epoch: 30/50
# Training Loss: 0.627196 	Validation Loss: 0.724793
# Training Accuracy: 93.40% 	Validation Accuracy: 81.67%
# Validation loss decreased (0.727347 --> 0.724793). Saving model ...
# Epoch: 31/50
# Training Loss: 0.623526 	Validation Loss: 0.725611
# Training Accuracy: 93.75% 	Validation Accuracy: 82.22%
# Epoch: 32/50
# Training Loss: 0.620542 	Validation Loss: 0.734802
# Training Accuracy: 94.17% 	Validation Accuracy: 81.94%
# Epoch: 33/50
# Training Loss: 0.616350 	Validation Loss: 0.722763
# Training Accuracy: 94.17% 	Validation Accuracy: 82.78%
# Validation loss decreased (0.724793 --> 0.722763). Saving model ...
# Epoch: 34/50
# Training Loss: 0.616645 	Validation Loss: 0.742606
# Training Accuracy: 94.58% 	Validation Accuracy: 80.28%
# Epoch: 35/50
# Training Loss: 0.610661 	Validation Loss: 0.715165
# Training Accuracy: 94.79% 	Validation Accuracy: 83.61%
# Validation loss decreased (0.722763 --> 0.715165). Saving model ...
# Epoch: 36/50
# Training Loss: 0.606245 	Validation Loss: 0.751461
# Training Accuracy: 95.56% 	Validation Accuracy: 79.44%
# Epoch: 37/50
# Training Loss: 0.607278 	Validation Loss: 0.714551
# Training Accuracy: 95.21% 	Validation Accuracy: 83.61%
# Validation loss decreased (0.715165 --> 0.714551). Saving model ...
# Epoch: 38/50
# Training Loss: 0.606258 	Validation Loss: 0.721267
# Training Accuracy: 95.14% 	Validation Accuracy: 81.94%
# Epoch: 39/50
# Training Loss: 0.602564 	Validation Loss: 0.709903
# Training Accuracy: 95.62% 	Validation Accuracy: 84.17%
# Validation loss decreased (0.714551 --> 0.709903). Saving model ...
# Epoch: 40/50
# Training Loss: 0.600656 	Validation Loss: 0.719305
# Training Accuracy: 95.56% 	Validation Accuracy: 83.06%
# Epoch: 41/50
# Training Loss: 0.599232 	Validation Loss: 0.707173
# Training Accuracy: 95.76% 	Validation Accuracy: 84.17%
# Validation loss decreased (0.709903 --> 0.707173). Saving model ...
# Epoch: 42/50
# Training Loss: 0.594192 	Validation Loss: 0.709157
# Training Accuracy: 96.74% 	Validation Accuracy: 83.33%
# Epoch: 43/50
# Training Loss: 0.591706 	Validation Loss: 0.721473
# Training Accuracy: 96.60% 	Validation Accuracy: 82.22%
# Epoch: 44/50
# Training Loss: 0.589586 	Validation Loss: 0.700053
# Training Accuracy: 97.01% 	Validation Accuracy: 85.83%
# Validation loss decreased (0.707173 --> 0.700053). Saving model ...
# Epoch: 45/50
# Training Loss: 0.591032 	Validation Loss: 0.732358
# Training Accuracy: 96.81% 	Validation Accuracy: 80.83%
# Epoch: 46/50
# Training Loss: 0.590538 	Validation Loss: 0.704717
# Training Accuracy: 96.94% 	Validation Accuracy: 83.89%
# Epoch: 47/50
# Training Loss: 0.586239 	Validation Loss: 0.701749
# Training Accuracy: 97.36% 	Validation Accuracy: 85.28%
# Epoch: 48/50
# Training Loss: 0.588086 	Validation Loss: 0.707756
# Training Accuracy: 96.74% 	Validation Accuracy: 84.44%
# Epoch: 49/50
# Training Loss: 0.583936 	Validation Loss: 0.706888
# Training Accuracy: 97.36% 	Validation Accuracy: 85.00%
# Epoch: 50/50
# Training Loss: 0.583507 	Validation Loss: 0.700785
# Training Accuracy: 97.22% 	Validation Accuracy: 84.44%
# Entrenamiento completo

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(valid_losses, label='Validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(frameon=False)

# %%
# Test
model.eval()  # se deshabilitan las capas de dropout
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        # print([img.size() for img in images])  # Esto imprimirá los tamaños de las imágenes en cada lote
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
          
    print('Test Accuracy of the model: {} %'.format(100 * correct / total))

# Save 
torch.save(model.state_dict(), 'vehcile_propio_cros.kpt')
# Out:
# Test Accuracy of the model: 81.33333333333333 %

# %%
# Funcion para visualizar las predicciones de test
def visualize_model(model, num_images):
    was_training = model.training
    
    model.eval()
    images_so_far = 0       
    
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
                    
            for j in range(inputs.size()[0]):
                images_so_far +=1
                ax = plt.subplot(num_images, 1, images_so_far)
                
                ax.axis('off')
                ax.set_title('Predicted: {} (Clase: {})'.format(class_names[preds[j]], class_names[labels[j]]))
                                
                imshow(inputs.cpu().data[j])
                
                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return           
                
        model.train(mode = was_training)

# %%
visualize_model(model=model, num_images = 4)
