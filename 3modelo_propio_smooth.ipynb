# %%
#Verifico la capacidad de GPU
# !nvidia-smi
# Out:
# Sun Nov 24 06:30:10 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.01             Driver Version: 537.70       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4050 ...    On  | 00000000:01:00.0 Off |                  N/A |
# | N/A   41C    P8               1W /  85W |   1961MiB /  6141MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      2771      C   /python3.12                               N/A      |
# |    0   N/A  N/A     37696      C   /python3.12                               N/A      |
# +---------------------------------------------------------------------------------------+

# %%
#Librerias a importar
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets, models, transforms

# %%
# Transformación para entrenamiento
train_transform = transforms.Compose([
    transforms.Resize(256),  # Cambia el tamaño para hacer el recorte centrado
    transforms.CenterCrop(224),  # Asegura el recorte centrado
    transforms.RandomHorizontalFlip(),  # Flip horizontal para aumentar los datos
    transforms.RandomVerticalFlip(),  # Flip vertical para aumentar los datos
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Transformaciones para validación
val_transform = transforms.Compose([
    transforms.Resize(256),  # Asegura el redimensionado
    transforms.CenterCrop(224),  # Recorta centrado
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Transformaciones para prueba
test_transform = transforms.Compose([
    transforms.Resize(256),  # Asegura el redimensionado
    transforms.CenterCrop(224),  # Recorta centrado
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])


# Cargar los datos con las nuevas transformaciones
train_dataset = torchvision.datasets.ImageFolder(root='/home/aloha/Lun9ntbk/imagenes_vehiculos/train', transform=train_transform)
val_dataset = torchvision.datasets.ImageFolder(root='/home/aloha/Lun9ntbk/imagenes_vehiculos/val', transform=val_transform)
test_dataset = torchvision.datasets.ImageFolder(root='/home/aloha/Lun9ntbk/imagenes_vehiculos/test', transform=test_transform)

print(train_dataset)
print(val_dataset)
print(test_dataset)
# Out:
# Dataset ImageFolder
#     Number of datapoints: 1800
#     Root location: /home/aloha/Lun9ntbk/imagenes_vehiculos/train
#     StandardTransform
# Transform: Compose(
#                Resize(size=256, interpolation=bilinear, max_size=None, antialias=True)
#                CenterCrop(size=(224, 224))
#                RandomHorizontalFlip(p=0.5)
#                RandomVerticalFlip(p=0.5)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )
# Dataset ImageFolder
#     Number of datapoints: 300
#     Root location: /home/aloha/Lun9ntbk/imagenes_vehiculos/val
#     StandardTransform
# Transform: Compose(
#                Resize(size=256, interpolation=bilinear, max_size=None, antialias=True)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )
# Dataset ImageFolder
#     Number of datapoints: 300
#     Root location: /home/aloha/Lun9ntbk/imagenes_vehiculos/test
#     StandardTransform
# Transform: Compose(
#                Resize(size=256, interpolation=bilinear, max_size=None, antialias=True)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
# Imprimo un resumen de los datos
print('Train:', len(train_dataset))
# Out:
# Train: 1800

# %%
import os
from torch.utils.data.sampler import SubsetRandomSampler # type: ignore

batch_size = 4
learning_rate = 0.001
num_epocas = 50
step_log = 100
num_workers = os.cpu_count()

# Porcentaje de datos de validación
valid_size = 0.20  # 20% para validación

# Obtener los índices para el dataset de entrenamiento y dividir para validación
num_train = len(train_dataset)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# Definir los samplers para entrenamiento y validación
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# Definir DataLoaders para entrenamiento, validación y test
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,
                                           sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,
                                           sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size,
                                          shuffle=True, num_workers=num_workers)

class_names = train_dataset.classes

print(f"Usando {num_workers} workers para cargar datos.")
# Out:
# Usando 16 workers para cargar datos.

# %%
# Imprimo el nombre de las clases
class_names = train_dataset.classes
print(train_dataset.classes)
# Out:
# ['Autos', 'Microbuses', 'Motos']

# %%
# Cargo un batch de imagenes
def imshow(inp, title = None):
  inp = inp.numpy().transpose((1, 2, 0))
  mean = np.array([0.485, 0.456, 0.406])
  std = np.array([0.229, 0.224, 0.225])
  inp = std * inp + mean
  inp = np.clip(inp, 0, 1)
  plt.imshow(inp)
  
  if title is not None:
    plt.title(title)
  plt.pause(0.001)
  
dataiter = iter(train_loader)
inputs, classes = next(dataiter)

out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
# Se grafican nuevamente, pero con los nombres de las clases truncados
def imshow_with_class_name(inp, class_name, ax=None):   
    
    if ax is None:
        ax = plt.gca()

    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    ax.imshow(inp)

      # Limit class name to 15 characters using slicing
    max_length = 15
    title = class_name[:max_length]  # Truncate at the specified index
    if len(class_name) > max_length:
        title += "..."  # Add ellipsis to indicate truncation

    ax.set_title(title, fontsize=8, ha='center', va='top')

dataiter = iter(train_loader)
inputs, classes = next(dataiter)

# Crear una cuadrícula de 2 filas y 2 columnas
fig, axes = plt.subplots(2, 2, figsize=(10, 10))

# Mostrar las imágenes y los nombres de las clases en cada subplot
for i, (inp, class_name) in enumerate(zip(inputs, classes)):
    row = i // 2
    col = i % 2
    imshow_with_class_name(inp, class_names[class_name], axes[row, col])

# Eliminar bordes y espacios entre subplots
plt.tight_layout()
plt.show()

# %%
torch.cuda.set_device(0) 
device = ('cuda' if torch.cuda.is_available() else 'cpu')

print("Se entrenara con:", device)
# Out:
# Se entrenara con: cuda

# %%
# Imprimo el numero de clases
num_classes = len(class_names)
print(num_classes)
# Out:
# 3

# %%
class Network(nn.Module):
    def __init__(self):
        super(Network, self).__init__()
        # Capas convolucionales
        self.conv1 = nn.Conv2d(3, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 256, kernel_size=3)
        self.bn1 = nn.BatchNorm2d(256)
        self.conv3 = nn.Conv2d(256, 512, kernel_size=3)
        
        # Capas completamente conectadas
        self.fc1 = nn.Linear(512*26*26, 50)  # Ajustar dimensiones según la salida de las convoluciones
        self.fc2 = nn.Linear(50, 3)  # 3 salidas para la clasificación (logits)

    def forward(self, x):
        # Aplicación de convoluciones, BatchNorm, ReLU y MaxPooling
        x = F.max_pool2d(F.relu(self.conv1(x)), 2)
        x = F.max_pool2d(F.relu(self.bn1(self.conv2(x))), 2)
        x = F.max_pool2d(F.relu(self.conv3(x)), 2)
        
        # Aplanar las características para las capas densas
        x = x.view(-1, self.num_flat_features(x))
        
        # Pasar por capas densas
        x = F.relu(self.fc1(x))
        x = self.fc2(x)  # Sin aplicar softmax aquí, ya que LabelSmoothingLoss lo maneja
        
        return x  # Logits sin normalizar

    def num_flat_features(self, x):
        size = x.size()[1:]  # Todas las dimensiones excepto el batch
        num_features = 1
        for s in size:
            num_features *= s
        return num_features
    
import torch
import torch.nn as nn
import torch.nn.functional as F

class LabelSmoothingLoss(nn.Module):
    def __init__(self, smoothing=0.0):
        """
        Constructor de LabelSmoothingLoss.
        smoothing: Valor de suavizado, entre 0.0 (sin suavizado) y 1.0 (total suavizado).
        """
        super(LabelSmoothingLoss, self).__init__()
        self.smoothing = smoothing
        self.criterion = nn.KLDivLoss(reduction='batchmean')  # Pérdida KLDiv

    def forward(self, pred, target):
        """
        pred: Salidas del modelo (logits), tamaño [batch_size, num_classes].
        target: Etiquetas verdaderas (clases), tamaño [batch_size].
        """
        num_classes = pred.size(1)
        # Crear distribución suavizada
        true_dist = torch.zeros_like(pred).fill_(self.smoothing / (num_classes - 1))
        true_dist.scatter_(1, target.unsqueeze(1), 1.0 - self.smoothing)
        
        # Calcular KLDiv entre predicciones (log-softmax) y distribución suavizada
        return self.criterion(F.log_softmax(pred, dim=1), true_dist)

# Instanciar el modelo
network = Network()

# %%
model = network.to(device)

# %%
# Definir la función de pérdida utilizando KLDivLoss
criterion = LabelSmoothingLoss(smoothing=0.1)
optimizer = torch.optim.SGD(model.parameters(), lr = learning_rate)

# %%
import os
import json

# Definir funciones para cargar y guardar métricas
def load_metrics(file_path):
    if os.path.exists(file_path):
        with open(file_path, 'r') as f:
            return json.load(f)
    return {"train_losses": [], "valid_losses": [], "accuracy_train_list": [], "accuracy_valid_list": []}

def save_metrics(file_path, metrics):
    with open(file_path, 'w') as f:
        json.dump(metrics, f)

# Ruta del archivo donde se guardarán las métricas
metrics_file = 'metrics_02.json'
metrics = load_metrics(metrics_file)

# Cargar las métricas anteriores
train_losses = metrics["train_losses"]
valid_losses = metrics["valid_losses"]
accuracy_train_list = metrics["accuracy_train_list"]
accuracy_valid_list = metrics["accuracy_valid_list"]

# Definir parámetros
valid_loss_min = min(valid_losses) if valid_losses else float('inf')  # Valor mínimo de valid_loss si existe

# Bucle de entrenamiento por épocas
for epoch in range(1, num_epocas + 1):
    # Inicializar las pérdidas de entrenamiento y validación
    train_loss = 0.0
    valid_loss = 0.0
    correct_train = 0  # Para contar las predicciones correctas en el entrenamiento
    total_train = 0  # Para contar el total de muestras de entrenamiento
    correct_valid = 0  # Para contar las predicciones correctas en la validación
    total_valid = 0  # Para contar el total de muestras de validación

    # ---- Entrenamiento ----
    model.train()  # Poner el modelo en modo de entrenamiento
    for data, target in train_loader:
        data, target = data.to(device), target.to(device)

        optimizer.zero_grad()  # Limpiar los gradientes
        output = model(data)  # Forward pass
        loss = criterion(output, target)  # Calcular la pérdida de entrenamiento
        loss.backward()  # Backward pass
        optimizer.step()  # Optimización

        train_loss += loss.item() * data.size(0)  # Actualizar pérdida
        _, pred = torch.max(output, dim=1)  # Predicciones
        correct_train += (pred == target).sum().item()  # Sumar correctas
        total_train += target.size(0)  # Total muestras

    # ---- Validación ----
    model.eval()  # Modo evaluación
    with torch.no_grad():
        for data, target in valid_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            loss = criterion(output, target)  # Calcular la pérdida de validación
            valid_loss += loss.item() * data.size(0)
            _, pred = torch.max(output, dim=1)
            correct_valid += (pred == target).sum().item()
            total_valid += target.size(0)

    # Calcular las pérdidas promediadas
    train_loss = train_loss / len(train_loader.sampler)
    valid_loss = valid_loss / len(valid_loader.sampler)

    # Calcular la precisión promedio en entrenamiento y validación
    train_accuracy = 100 * correct_train / total_train
    valid_accuracy = 100 * correct_valid / total_valid

    # Guardar las pérdidas y las precisiones
    train_losses.append(train_loss)
    valid_losses.append(valid_loss)
    accuracy_train_list.append(train_accuracy)
    accuracy_valid_list.append(valid_accuracy)

    # Imprimir resultados por época
    print(f'Epoch: {epoch}/{num_epocas}')
    print(f'Training Loss: {train_loss:.6f} \tValidation Loss: {valid_loss:.6f}')
    print(f'Training Accuracy: {train_accuracy:.2f}% \tValidation Accuracy: {valid_accuracy:.2f}%')

    # Guardar el modelo si la pérdida de validación ha disminuido
    if valid_loss <= valid_loss_min:
        print(f'Validation loss decreased ({valid_loss_min:.6f} --> {valid_loss:.6f}). Saving model ...')
        torch.save(model.state_dict(), 'vehcile_propio_smooth.pt')  # Guardar modelo
        valid_loss_min = valid_loss  # Actualizar mejor pérdida

    # Guardar métricas actualizadas
    save_metrics(metrics_file, {
        "train_losses": train_losses,
        "valid_losses": valid_losses,
        "accuracy_train_list": accuracy_train_list,
        "accuracy_valid_list": accuracy_valid_list
    })

# Finalización del entrenamiento
print("Entrenamiento completo")
# Out:
# Epoch: 1/40
# Training Loss: 0.688607 	Validation Loss: 0.652833
# Training Accuracy: 42.29% 	Validation Accuracy: 45.00%
# Validation loss decreased (inf --> 0.652833). Saving model ...
# Epoch: 2/40
# Training Loss: 0.613373 	Validation Loss: 0.627910
# Training Accuracy: 52.01% 	Validation Accuracy: 50.83%
# Validation loss decreased (0.652833 --> 0.627910). Saving model ...
# Epoch: 3/40
# Training Loss: 0.552594 	Validation Loss: 0.584080
# Training Accuracy: 58.75% 	Validation Accuracy: 54.17%
# Validation loss decreased (0.627910 --> 0.584080). Saving model ...
# Epoch: 4/40
# Training Loss: 0.505730 	Validation Loss: 0.536072
# Training Accuracy: 63.54% 	Validation Accuracy: 62.22%
# Validation loss decreased (0.584080 --> 0.536072). Saving model ...
# Epoch: 5/40
# Training Loss: 0.477687 	Validation Loss: 0.517391
# Training Accuracy: 66.39% 	Validation Accuracy: 62.78%
# Validation loss decreased (0.536072 --> 0.517391). Saving model ...
# Epoch: 6/40
# Training Loss: 0.435201 	Validation Loss: 0.476512
# Training Accuracy: 68.68% 	Validation Accuracy: 70.28%
# Validation loss decreased (0.517391 --> 0.476512). Saving model ...
# Epoch: 7/40
# Training Loss: 0.393605 	Validation Loss: 0.454080
# Training Accuracy: 75.07% 	Validation Accuracy: 72.22%
# Validation loss decreased (0.476512 --> 0.454080). Saving model ...
# Epoch: 8/40
# Training Loss: 0.351359 	Validation Loss: 0.443932
# Training Accuracy: 77.22% 	Validation Accuracy: 71.39%
# Validation loss decreased (0.454080 --> 0.443932). Saving model ...
# Epoch: 9/40
# Training Loss: 0.314216 	Validation Loss: 0.399207
# Training Accuracy: 79.51% 	Validation Accuracy: 73.33%
# Validation loss decreased (0.443932 --> 0.399207). Saving model ...
# Epoch: 10/40
# Training Loss: 0.282682 	Validation Loss: 0.353347
# Training Accuracy: 83.12% 	Validation Accuracy: 74.72%
# Validation loss decreased (0.399207 --> 0.353347). Saving model ...
# Epoch: 11/40
# Training Loss: 0.253943 	Validation Loss: 0.353397
# Training Accuracy: 85.35% 	Validation Accuracy: 78.33%
# Epoch: 12/40
# Training Loss: 0.235086 	Validation Loss: 0.367113
# Training Accuracy: 87.50% 	Validation Accuracy: 75.56%
# Epoch: 13/40
# Training Loss: 0.216832 	Validation Loss: 0.319500
# Training Accuracy: 88.40% 	Validation Accuracy: 79.72%
# Validation loss decreased (0.353347 --> 0.319500). Saving model ...
# Epoch: 14/40
# Training Loss: 0.195022 	Validation Loss: 0.319546
# Training Accuracy: 89.58% 	Validation Accuracy: 78.89%
# Epoch: 15/40
# Training Loss: 0.172377 	Validation Loss: 0.323778
# Training Accuracy: 91.39% 	Validation Accuracy: 80.83%
# Epoch: 16/40
# Training Loss: 0.156491 	Validation Loss: 0.329000
# Training Accuracy: 93.40% 	Validation Accuracy: 79.72%
# Epoch: 17/40
# Training Loss: 0.139533 	Validation Loss: 0.287348
# Training Accuracy: 94.03% 	Validation Accuracy: 83.33%
# Validation loss decreased (0.319500 --> 0.287348). Saving model ...
# Epoch: 18/40
# Training Loss: 0.125469 	Validation Loss: 0.321871
# Training Accuracy: 94.72% 	Validation Accuracy: 80.28%
# Epoch: 19/40
# Training Loss: 0.108721 	Validation Loss: 0.344330
# Training Accuracy: 96.74% 	Validation Accuracy: 76.67%
# Epoch: 20/40
# Training Loss: 0.098437 	Validation Loss: 0.309231
# Training Accuracy: 96.81% 	Validation Accuracy: 80.28%
# Epoch: 21/40
# Training Loss: 0.093011 	Validation Loss: 0.254580
# Training Accuracy: 97.29% 	Validation Accuracy: 83.33%
# Validation loss decreased (0.287348 --> 0.254580). Saving model ...
# Epoch: 22/40
# Training Loss: 0.084951 	Validation Loss: 0.285105
# Training Accuracy: 97.36% 	Validation Accuracy: 79.44%
# Epoch: 23/40
# Training Loss: 0.072472 	Validation Loss: 0.296623
# Training Accuracy: 98.40% 	Validation Accuracy: 81.39%
# Epoch: 24/40
# Training Loss: 0.067485 	Validation Loss: 0.256120
# Training Accuracy: 98.61% 	Validation Accuracy: 83.33%
# Epoch: 25/40
# Training Loss: 0.057810 	Validation Loss: 0.291881
# Training Accuracy: 98.96% 	Validation Accuracy: 81.67%
# Epoch: 26/40
# Training Loss: 0.057607 	Validation Loss: 0.251035
# Training Accuracy: 98.75% 	Validation Accuracy: 83.61%
# Validation loss decreased (0.254580 --> 0.251035). Saving model ...
# Epoch: 27/40
# Training Loss: 0.052461 	Validation Loss: 0.252957
# Training Accuracy: 99.24% 	Validation Accuracy: 83.89%
# Epoch: 28/40
# Training Loss: 0.046254 	Validation Loss: 0.264281
# Training Accuracy: 99.58% 	Validation Accuracy: 85.28%
# Epoch: 29/40
# Training Loss: 0.042917 	Validation Loss: 0.239169
# Training Accuracy: 99.24% 	Validation Accuracy: 85.56%
# Validation loss decreased (0.251035 --> 0.239169). Saving model ...
# Epoch: 30/40
# Training Loss: 0.041498 	Validation Loss: 0.244255
# Training Accuracy: 99.24% 	Validation Accuracy: 85.00%
# Epoch: 31/40
# Training Loss: 0.036062 	Validation Loss: 0.225911
# Training Accuracy: 99.65% 	Validation Accuracy: 86.39%
# Validation loss decreased (0.239169 --> 0.225911). Saving model ...
# Epoch: 32/40
# Training Loss: 0.032255 	Validation Loss: 0.232580
# Training Accuracy: 99.86% 	Validation Accuracy: 85.28%
# Epoch: 33/40
# Training Loss: 0.028915 	Validation Loss: 0.237152
# Training Accuracy: 99.86% 	Validation Accuracy: 84.72%
# Epoch: 34/40
# Training Loss: 0.028160 	Validation Loss: 0.231484
# Training Accuracy: 99.79% 	Validation Accuracy: 85.00%
# Epoch: 35/40
# Training Loss: 0.026424 	Validation Loss: 0.231834
# Training Accuracy: 99.86% 	Validation Accuracy: 85.28%
# Epoch: 36/40
# Training Loss: 0.024221 	Validation Loss: 0.236571
# Training Accuracy: 99.86% 	Validation Accuracy: 84.72%
# Epoch: 37/40
# Training Loss: 0.022131 	Validation Loss: 0.234392
# Training Accuracy: 99.93% 	Validation Accuracy: 85.28%
# Epoch: 38/40
# Training Loss: 0.019601 	Validation Loss: 0.229478
# Training Accuracy: 99.93% 	Validation Accuracy: 84.17%
# Epoch: 39/40
# Training Loss: 0.018226 	Validation Loss: 0.229579
# Training Accuracy: 99.93% 	Validation Accuracy: 85.83%
# Epoch: 40/40
# Training Loss: 0.018553 	Validation Loss: 0.233676
# Training Accuracy: 99.93% 	Validation Accuracy: 85.56%
# Entrenamiento completo

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(valid_losses, label='Validation loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(frameon=False)

# %%
# Test
model.eval()  # se deshabilitan las capas de dropout
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        # print([img.size() for img in images])  # Esto imprimirá los tamaños de las imágenes en cada lote
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
          
    print('Test Accuracy of the model: {} %'.format(100 * correct / total))

# Save 
torch.save(model.state_dict(), 'vehcile_propio_smooth.ckpt')
# Out:
# Test Accuracy of the model: 80.0 %

# %%
# Funcion para visualizar las predicciones de test
def visualize_model(model, num_images):
    was_training = model.training
    
    model.eval()
    images_so_far = 0       
    
    with torch.no_grad():
        for i, (inputs, labels) in enumerate(test_loader):
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
                    
            for j in range(inputs.size()[0]):
                images_so_far +=1
                ax = plt.subplot(num_images, 1, images_so_far)
                
                ax.axis('off')
                ax.set_title('Predicted: {} (Clase: {})'.format(class_names[preds[j]], class_names[labels[j]]))
                                
                imshow(inputs.cpu().data[j])
                
                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return           
                
        model.train(mode = was_training)

# %%
visualize_model(model=model, num_images = 4)
